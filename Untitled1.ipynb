# %%
import numpy as np
import pandas as pd
! pip install lxml
! pip install html5lib
! pip install BeautifulSoup4

# %%
df = pd.read_html('https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/')
df[0]
# Out:
#                          Bank NameBank           CityCity StateSt  CertCert  \
# 0                    Almena State Bank             Almena      KS     15426
# 1           First City Bank of Florida  Fort Walton Beach      FL     16748
# 2                 The First State Bank      Barboursville      WV     14361
# 3                   Ericson State Bank            Ericson      NE     18265
# 4     City National Bank of New Jersey             Newark      NJ     21111
# ..                                 ...                ...     ...       ...
# 558                 Superior Bank, FSB           Hinsdale      IL     32646
# 559                Malta National Bank              Malta      OH      6629
# 560    First Alliance Bank & Trust Co.         Manchester      NH     34264
# 561  National State Bank of Metropolis         Metropolis      IL      3815
# 562                   Bank of Honolulu           Honolulu      HI     21029
#
# ...

# %%
df=df[0]

# %%
# to change name of a column
new_names = ['NameBank', 'City', 'State' , 'Cert', 'AI', 'ClosingDate', 'Fund']

# %%
df.columns = new_names

# %%
df['date'] = pd.to_datetime(df['ClosingDate'])

# %%
# dropping the close_date column
df.drop('ClosingDate',axis=1,inplace=True)
df.head()
# Out:
#                            NameBank               City State   Cert  \
# 0                 Almena State Bank             Almena    KS  15426
# 1        First City Bank of Florida  Fort Walton Beach    FL  16748
# 2              The First State Bank      Barboursville    WV  14361
# 3                Ericson State Bank            Ericson    NE  18265
# 4  City National Bank of New Jersey             Newark    NJ  21111
#
#                            AI   Fund       date
# 0                 Equity Bank  10538 2020-10-23
# 1   United Fidelity Bank, fsb  10537 2020-10-16
# 2              MVB Bank, Inc.  10536 2020-04-03
# 3  Farmers and Merchants Bank  10535 2020-02-14
# 4             Industrial Bank  10534 2019-11-01

# %%
df['date'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
#df['date'] = df['date'].apply(lambda x: x.split('-'))

# %%
df['date'] = df['date'].astype('string')

# %%
df['date'].dtypes
# Out:
# string[python]

# %%
df['Year']=df['date'].apply(lambda x: x.split('-')[0])
df['Month']=df['date'].apply(lambda x: x.split('-')[1])
df['Day']=df['date'].apply(lambda x: x.split('-')[2])

# %%
pd.set_option('display.max_columns',None)
df.head()
# Out:
#                            NameBank               City State   Cert  \
# 0                 Almena State Bank             Almena    KS  15426
# 1        First City Bank of Florida  Fort Walton Beach    FL  16748
# 2              The First State Bank      Barboursville    WV  14361
# 3                Ericson State Bank            Ericson    NE  18265
# 4  City National Bank of New Jersey             Newark    NJ  21111
#
#                            AI   Fund        date  Year Month Day
# 0                 Equity Bank  10538  2020-10-23  2020    10  23
# 1   United Fidelity Bank, fsb  10537  2020-10-16  2020    10  16
# 2              MVB Bank, Inc.  10536  2020-04-03  2020    04  03
# 3  Farmers and Merchants Bank  10535  2020-02-14  2020    02  14
# 4             Industrial Bank  10534  2019-11-01  2019    11  01

# %%
df.drop('date', axis=1, inplace=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 df.drop('date', axis=1, inplace=True)
#       2 df.head()
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
# ...

# %%
for idx, row in df.iterrows():
    print(row['State'])
# Out:
# KS
# FL
# WV
# NE
# NJ
# OH
# KY
# TX
# IL
# KS
# IL
# WI
# LA
# UT
# IL
# NJ
# AR
# GA
# PA
# TN
# WI
# WA
# GA
# CO
# IL
# PR
# GA
# IL
# FL
# MN
# CA
# IL
# MD
# IL
# GA
# OK
# FL
# IL
# MD
# OH
# IL
# SC
# PA
# VA
# ID
# OK
# IL
# TX
# FL
# TX
# CT
# AZ
# TN
# WI
# FL
# TN
# NV
# WI
# AZ
# GA
# NC
# GA
# NC
# FL
# FL
# KY
# AZ
# GA
# IL
# MN
# WA
# MO
# GA
# IL
# FL
# PA
# MO
# FL
# FL
# IL
# MO
# MN
# IL
# GA
# IL
# KS
# GA
# GA
# FL
# MO
# GA
# TN
# GA
# FL
# NC
# IL
# SC
# OK
# AL
# FL
# CA
# SC
# MN
# MD
# MD
# NJ
# MI
# IL
# GA
# IL
# GA
# MN
# GA
# IN
# IL
# TN
# MN
# TN
# FL
# PA
# GA
# FL
# AZ
# FL
# LA
# IA
# GA
# UT
# NE
# IL
# CO
# GA
# GA
# FL
# IL
# NJ
# NC
# GA
# MO
# MN
# TX
# CA
# VA
# FL
# GA
# GA
# IL
# GA
# FL
# PA
# KS
# WA
# IL
# IN
# SC
# VA
# CO
# FL
# FL
# AZ
# FL
# GA
# GA
# CO
# CO
# IL
# GA
# FL
# GA
# SC
# WA
# WA
# GA
# GA
# FL
# MI
# GA
# GA
# FL
# FL
# MS
# MN
# AL
# AL
# GA
# GA
# NV
# IL
# IL
# WI
# OK
# IL
# CA
# CA
# GA
# GA
# CA
# WI
# MI
# FL
# ...
